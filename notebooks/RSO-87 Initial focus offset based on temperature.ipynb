# %% [markdown]
# # RSO-87 Initial focus offset based on temperature
#
# We can use all the alignment runs and plot the final solution as a function of truss temperature (v mode 4) and update the focus offset in the open loop model at the beginning of the night.
#
#
# ## Initial Alignment
#
# Let's start by mining the initial alignment.

# %%
day_obs_begin = 20260101
day_obs_end = 20260131

# %%
from lsst_efd_client import EfdClient

# Create an EFD client instance
client = EfdClient('usdf_efd')

# %%
from lsst.summit.utils.efdUtils import getEfdData, makeEfdClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from lsst.summit.utils.efdUtils import getEfdData, makeEfdClient
#
# File ~/miniforge3/envs/lsst-scipipe-10.1.0/lib/python3.12/site-packages/lsst/summit/utils/__init__.py:22
#       1 # This file is part of summit_utils.
#       2 #
#       3 # Developed for the LSST Data Management System.
#    (...)     19 # You should have received a copy of the GNU General Public License
#      20 # along with this program.  If not, see <https://www.gnu.org/licenses/>.
# ---> 22 from .bestEffort import *
#      23 from .butlerUtils import *
#      24 from .consdbClient import *
#
# File ~/miniforge3/envs/lsst-scipipe-10.1.0/lib/python3.12/site-packages/lsst/summit/utils/bestEffort.py:26
#      23 import logging
#      24 from typing import Any
# ---> 26 import lsst.afw.image as afwImage
#      27 import lsst.daf.butler as dafButler
#      28 from lsst.daf.butler.registry import ConflictingDefinitionError
#
# ModuleNotFoundError: No module named 'lsst.afw'
